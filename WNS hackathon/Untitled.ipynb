# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ezchave\Desktop\Final Survey Data (1).csv',error_bad_lines =False)

# %%
x_data = df.copy()

mms = MinMaxScaler()
mms.fit(x_data)
data_transformed = mms.transform(x_data)

Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### Optimum number of clusters are 4

# %%
X = x_data.values[:,1:]
X = np.nan_to_num(X)

# %%
#choosing k = 4 as it's best
clusterNum = 4
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)
df['labels'] = 0
for i,lbl in zip(df.index,labels) :
    df.at[i,'labels'] = lbl
# Out:
# [1 1 3 1 2 2 3 2 0 1 3 1 3 1 2 3 0 0 3 1 1 1 0 3 2 0 0 3 0 0 0 1 1 2 3 0 3
#  2 3 3 1 0 0 0 0 3 0 1 2 3 1 0 2 0 1 3 1 2 1 3 0 1 3 2 0 0 3 2 1 3 3 3 2 1
#  3 3 0 1 1 1 0 2 0 2 1 0 0 1 3 2 2 0 3 0 1 1 3 3 0 1 1 3 2 0 1 0 0 1 3 2 1
#  2 3 1 1 3 1 0 3 1 2 0 1 0 3 3 3 1 1 3 0 0 2 0 0 0 0 2 3 3 0 0 0 3 3 1 2 3
#  1 3 1 0 0 1 3 1 2 2 0 0 2 1 2 0 3 0 1 3 1 1 3 1 0 0 3 0 0 0 3 3 3 3 3 3 0
#  3 0 3 0 2 0 3 0 1 3 1 2 3 3 3 3 0 0 0 0 0 3 0 1 2 1 3 3 3 1 3 0 3 0 0 0 3
#  2 2 0 2 0 0 0 3 1 1 3 1 1 3 1 1 1 3 0 3 0 2 0 0 2 0 2 3 0 1 0 2 3 2 0 2 1
#  0 3 3]

# %%
cluster = [1,2,3,4]
for i in range(0,4) :
    cluster[i] = df[df.labels == (i)]

# %%
df.head() # showing the top 5 rows
# Out:
#    Customer  Having more RAM in my phone is very important to me  \
# 0         1                                                  3
# 1         2                                                  3
# 2         3                                                  5
# 3         4                                                  3
# 4         5                                                  1
#
#    Most of the data is stored in my phone, rather than my laptop  \
# 0                                                  2
# 1                                                  2
# 2                                                  5
# 3                                                  2
# 4                                                  3
#
#    I’d rather buy gadgets from retail stores like Croma, Reliance Digital etc  \
# 0                                                  4
# 1                                                  4
# 2                                                  1
# ...

# %%
cluster[0].head()
# Out:
#     Customer  Having more RAM in my phone is very important to me  \
# 8          9                                                  4
# 16        17                                                  4
# 17        18                                                  4
# 22        23                                                  4
# 25        26                                                  4
#
#     Most of the data is stored in my phone, rather than my laptop  \
# 8                                                   2
# 16                                                  2
# 17                                                  2
# 22                                                  2
# 25                                                  2
#
#     I’d rather buy gadgets from retail stores like Croma, Reliance Digital etc  \
# 8                                                   2
# 16                                                  2
# ...

# %%
cluster[1].head()
# Out:
#     Customer  Having more RAM in my phone is very important to me  \
# 0          1                                                  3
# 1          2                                                  3
# 3          4                                                  3
# 9         10                                                  3
# 11        12                                                  3
#
#     Most of the data is stored in my phone, rather than my laptop  \
# 0                                                   2
# 1                                                   2
# 3                                                   2
# 9                                                   2
# 11                                                  2
#
#     I’d rather buy gadgets from retail stores like Croma, Reliance Digital etc  \
# 0                                                   4
# 1                                                   4
# ...

# %%
cluster[2].head()
# Out:
#     Customer  Having more RAM in my phone is very important to me  \
# 4          5                                                  1
# 5          6                                                  1
# 7          8                                                  1
# 14        15                                                  1
# 24        25                                                  1
#
#     Most of the data is stored in my phone, rather than my laptop  \
# 4                                                   3
# 5                                                   3
# 7                                                   3
# 14                                                  3
# 24                                                  3
#
#     I’d rather buy gadgets from retail stores like Croma, Reliance Digital etc  \
# 4                                                   5
# 5                                                   5
# ...

# %%
cluster[3].head()
# Out:
#     Customer  Having more RAM in my phone is very important to me  \
# 2          3                                                  5
# 6          7                                                  5
# 10        11                                                  5
# 12        13                                                  5
# 15        16                                                  5
#
#     Most of the data is stored in my phone, rather than my laptop  \
# 2                                                   5
# 6                                                   5
# 10                                                  5
# 12                                                  5
# 15                                                  5
#
#     I’d rather buy gadgets from retail stores like Croma, Reliance Digital etc  \
# 2                                                   1
# 6                                                   1
# ...

# %%
for i in range(0,4):
    cluster[i].to_csv(r'C:\Users\ezchave\Desktop\cluster_'+str(i)+'.csv')

# %%
df.to_csv(r'C:\Users\ezchave\Desktop\clustered_df.csv')
